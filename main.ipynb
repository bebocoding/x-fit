# %%
systemMessage = """
    You are a gym coach who writes a detailed 2 weeks training plans. The training plan is tailored to user's goal, fitness level, prefrences.
    The plan is customized by the user.
    The plan can include the following activites:
    gym workout (with details on number of sets and reps)
    
    Remember to include instructions about the activity
    Your response should only be in json format.
"""

# %%
tools = [{
    "type": "function",
    "function": {
        "name": "trainingFromJson",
        "description": "training plan from json",
    
        "parameters": {
                "type": "object",
                "properties": {
                    "^week [1-4]+$":{
                        "^day [1-7]+$": {
                            "type": "object",
                            "properties": {
                                "gymWorkout": {
                                    "type": "array",
                                    "description": "array of workouts",
                                    "items":{
                                        "properties":{
                                            "exerciseName": {
                                                "type": "string",
                                                "description": "name of exercise"
                                            },
                                            "numberOfSets":{
                                                "type": "number",
                                                "description": "number of sets"
                                            },
                                            "numberOfReps": {
                                                "type": "number",
                                                "description": "number of reps"
                                            },
                                            "duration": {
                                                "type": "number",
                                                "description": "duration in minutes"
                                            },
                                            "description": {
                                                "type": "string",
                                                "description": "instructions about the exercise"
                                            }
                                        },
                                        "required": ["numberOfSets", "numberOfReps", "duration", "description"]
                                    }
                                }
                            }
                        }
                }
            }
        }
}}
]

# %%
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage

from aiCoach import AiCoach
import models

aiCoach = AiCoach()

# %%
example = {"gender": "Male",
            "age": 25,
            "weight": 75.5,
            "height": 180.0,
            "goal": ["Build muscle", "Improve endurance"],
            "experience": "Intermediate",
            "bodyFatPercentage": 15.5,
            "muscleMass": 35.0,
            "workoutDurationPreference": "60 minutes",
            "workoutFrequencyPreference": "5 times a week",
            "preferredExerciseTypes": ["Weight lifting", "Running"],
            "trainingEnvironmentPreference": ["Gym", "Outdoor"],
            "healthIssues": ["Asthma"]
            }
userData = models.UserData(**example)
userPrompt = aiCoach.generateUserPrompt(userData)
print(userPrompt)
# Out:
# I am a Male.
# My age is 25.
# My height 180.0 meters.
# My weight is 75.5 kg.
# My goal is to Build muscle, Improve endurance.
# I am at 15.5% fat percentage.
# My muscle mass is 35.0 kg.
# I prefer to have a 60 minutes min workout.
# I prefer to train 5 times a week .
# I prefer Weight lifting, Running exercise types.
# I am at Intermediate level.
# I like to workout Gym, Outdoor.
# I have Asthma.

# %%
llm = ChatGroq(model="llama3-70b-8192", api_key="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", temperature=1)

messages = [
    SystemMessage(content=systemMessage),
    HumanMessage(content=userPrompt),
]
print(llm.invoke(messages).content)
# Out:
# Here is your customized 2-week training plan:
#
# ```
# {
#   "weeks": 2,
#   "goal": "Build muscle, Improve endurance",
#   "workouts_per_week": 5,
#   "workout_duration": 60,
#   "fitness_level": "Intermediate",
#   "exercise_types": ["Weight lifting", "Running"],
#   "preferred_locations": ["Gym", "Outdoor"],
#   "medical_conditions": ["Asthma"],
#
#   "week1": {
#     "monday": {
#       "gym": {
#         "warm_up": "5-10 minutes on the treadmill or stationary bike",
#         "exercises": [
#           {"exercise": "Squats", "sets": 3, "reps": 8-12},
#           {"exercise": "Leg Press", "sets": 3, "reps": 10-15},
#           {"exercise": "Lunges", "sets": 3, "reps": 10-12},
#           {"exercise": "Leg Extensions", "sets": 3, "reps": 12-15},
#           {"exercise": "Leg Curls", "sets": 3, "reps": 10-12}
#         ],
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "tuesday": {
#       "outdoor": {
#         "warm_up": "5-10 minutes of walking or jogging",
#         "exercise": "Running",
#         "duration": 20-30 minutes,
#         "intensity": "Moderate",
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "wednesday": {
#       "gym": {
#         "warm_up": "5-10 minutes on the treadmill or stationary bike",
#         "exercises": [
#           {"exercise": "Bench Press", "sets": 3, "reps": 8-12},
#           {"exercise": "Incline Dumbbell Press", "sets": 3, "reps": 10-12},
#           {"exercise": "Cable Flyes", "sets": 3, "reps": 12-15},
#           {"exercise": "Bent Over Dumbbell Rows", "sets": 3, "reps": 8-10},
#           {"exercise": "Lat Pulldowns", "sets": 3, "reps": 10-12}
#         ],
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "thursday": {
#       "outdoor": {
#         "warm_up": "5-10 minutes of walking or jogging",
#         "exercise": "Running",
#         "duration": 20-30 minutes,
#         "intensity": "Moderate",
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "friday": {
#       "gym": {
#         "warm_up": "5-10 minutes on the treadmill or stationary bike",
#         "exercises": [
#           {"exercise": "Deadlifts", "sets": 3, "reps": 8-10},
#           {"exercise": "Bent Over Barbell Rows", "sets": 3, "reps": 8-10},
#           {"exercise": "Pull-ups", "sets": 3, "reps": as many as possible},
#           {"exercise": "Dumbbell Bicep Curls", "sets": 3, "reps": 10-12},
#           {"exercise": "Tricep Dips", "sets": 3, "reps": 12-15}
#         ],
#         "cool_down": "5-10 minutes of stretching"
#       }
#     }
#   },
#
#   "week2": {
#     "monday": {
#       "gym": {
#         "warm_up": "5-10 minutes on the treadmill or stationary bike",
#         "exercises": [
#           {"exercise": "Leg Press", "sets": 3, "reps": 10-12},
#           {"exercise": "Lunges", "sets": 3, "reps": 10-12},
#           {"exercise": "Leg Extensions", "sets": 3, "reps": 12-15},
#           {"exercise": "Leg Curls", "sets": 3, "reps": 10-12},
#           {"exercise": "Calf Raises", "sets": 3, "reps": 12-15}
#         ],
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "tuesday": {
#       "outdoor": {
#         "warm_up": "5-10 minutes of walking or jogging",
#         "exercise": "Running",
#         "duration": 20-30 minutes,
#         "intensity": "Moderate",
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "wednesday": {
#       "gym": {
#         "warm_up": "5-10 minutes on the treadmill or stationary bike",
#         "exercises": [
#           {"exercise": "Incline Bench Press", "sets": 3, "reps": 8-10},
#           {"exercise": "Dumbbell Chest Press", "sets": 3, "reps": 10-12},
#           {"exercise": "Cable Crossovers", "sets": 3, "reps": 12-15},
#           {"exercise": "Seated Cable Rows", "sets": 3, "reps": 8-10},
#           {"exercise": "Lat Pulldowns", "sets": 3, "reps": 10-12}
#         ],
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "thursday": {
#       "outdoor": {
#         "warm_up": "5-10 minutes of walking or jogging",
#         "exercise": "Running",
#         "duration": 20-30 minutes,
#         "intensity": "Moderate",
#         "cool_down": "5-10 minutes of stretching"
#       }
#     },
#     "friday": {
#       "gym": {
#         "warm_up": "5-10 minutes on the treadmill or stationary bike",
#         "exercises": [
#           {"exercise": "Bent Over Barbell Rows", "sets": 3, "reps": 8-10},
#           {"exercise": "Pull-ups", "sets": 3, "reps": as many as possible},
#           {"exercise": "Dumbbell Bicep Curls", "sets": 3, "reps": 10-12},
#           {"exercise": "Tricep Dips", "sets": 3, "reps": 12-15},
#           {"exercise": "Shoulder Press", "sets": 3, "reps": 8-10}
#         ],
#         "cool_down": "5-10 minutes of stretching"
#       }
#     }
#   }
# }
# ```
# Remember to:
#
# * Start with a weight that allows you to complete the given number of reps with good form.
# * Gradually increase the weight as you get stronger.
# * Rest for 60-90 seconds between sets, and 120-180 seconds between exercises.
# * Stay hydrated and fuel your body with a balanced diet.
# * Consult with a doctor or a medical professional before starting any new exercise program, especially with asthma.
#
# Good luck and have fun!

# %%
llm_with_tools = llm.bind_tools(tools=tools, tool_choice="trainingFromJson")

llm_with_tools.invoke(messages).tool_calls[0]['args']
# Out:
# {'week 1': {'day 1': {'gymWorkout': [{'exerciseName': 'Bench Press',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of bench press with 60 sec rest between sets'},
#     {'exerciseName': 'Incline Dumbbell Press',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of incline dumbbell press with 60 sec rest between sets'},
#     {'exerciseName': ' Bent Over Dumbbell Row',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of bent over dumbbell row with 60 sec rest between sets'}]},
#   'day 2': {'gymWorkout': [{'exerciseName': 'Squats',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of squats with 60 sec rest between sets'},
#     {'exerciseName': 'Leg Press',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of leg press with 60 sec rest between sets'},
#     {'exerciseName': 'Lunges',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of lunges with 60 sec rest between sets'}]},
#   'day 3': {'gymWorkout': [{'exerciseName': 'Pull-ups',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of pull-ups with 60 sec rest between sets'},
#     {'exerciseName': 'Dumbbell Bicep Curl',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of dumbbell bicep curl with 60 sec rest between sets'},
#     {'exerciseName': 'Tricep Dips',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of tricep dips with 60 sec rest between sets'}]},
#   'day 4': {'gymWorkout': [{'exerciseName': 'Deadlifts',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of deadlifts with 60 sec rest between sets'},
#     {'exerciseName': 'Shoulder Press',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of shoulder press with 60 sec rest between sets'},
#     {'exerciseName': 'Bicycle Crunches',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of bicycle crunches with 60 sec rest between sets'}]},
#   'day 5': {'gymWorkout': [{'exerciseName': 'Running',
#      'numberOfSets': 1,
#      'numberOfReps': 1,
#      'duration': 60,
#      'description': 'Warm up with 5 min on the treadmill, then do 60 min of running at moderate intensity'}]}},
#  'week 2': {'day 1': {'gymWorkout': [{'exerciseName': 'Incline Bench Press',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of incline bench press with 60 sec rest between sets'},
#     {'exerciseName': 'Bent Over Barbell Row',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of bent over barbell row with 60 sec rest between sets'},
#     {'exerciseName': 'Tricep Extensions',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of tricep extensions with 60 sec rest between sets'}]},
#   'day 2': {'gymWorkout': [{'exerciseName': 'Leg Press',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of leg press with 60 sec rest between sets'},
#     {'exerciseName': 'Lunges',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of lunges with 60 sec rest between sets'},
#     {'exerciseName': 'Calf Raises',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of calf raises with 60 sec rest between sets'}]},
#   'day 3': {'gymWorkout': [{'exerciseName': 'Pull-ups',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of pull-ups with 60 sec rest between sets'},
#     {'exerciseName': 'Dumbbell Bicep Curl',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of dumbbell bicep curl with 60 sec rest between sets'},
#     {'exerciseName': 'Tricep Dips',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of tricep dips with 60 sec rest between sets'}]},
#   'day 4': {'gymWorkout': [{'exerciseName': 'Deadlifts',
#      'numberOfSets': 3,
#      'numberOfReps': 8,
#      'duration': 30,
#      'description': 'Warm up with 5 min on the treadmill, then do 3 sets of 8 reps of deadlifts with 60 sec rest between sets'},
#     {'exerciseName': 'Shoulder Press',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of shoulder press with 60 sec rest between sets'},
#     {'exerciseName': 'Bicycle Crunches',
#      'numberOfSets': 3,
#      'numberOfReps': 10,
#      'duration': 30,
#      'description': 'Do 3 sets of 10 reps of bicycle crunches with 60 sec rest between sets'}]},
#   'day 5': {'gymWorkout': [{'exerciseName': 'Running',
#      'numberOfSets': 1,
#      'numberOfReps': 1,
#      'duration': 60,
#      'description': 'Warm up with 5 min on the treadmill, then do 60 min of running at moderate intensity'}]}}}

# %%
from schemas import *

aiCoach = AiCoach()

example = {"gender": "Male",
            "age": 25,
            "weight": 75.5,
            "height": 180.0,
            "goal": ["Build muscle", "Improve endurance"],
            "experience": "Intermediate",
            "bodyFatPercentage": 15.5,
            "muscleMass": 35.0,
            "workoutDurationPreference": "60 minutes",
            "workoutFrequencyPreference": "5 times a week",
            "preferredExerciseTypes": ["Weight lifting", "Running"],
            "trainingEnvironmentPreference": ["Gym", "Outdoor"],
            "healthIssues": ["Asthma"]
            } 

userData = UserData(**example)

aiCoach.generatePlan(userData)
# Out:
# f:\grad\venv\Lib\site-packages\pydantic\_internal\_config.py:334: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# {'week 1': {'day 1': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Squats: 3 sets of 8 reps',
#      'duration': 30,
#      'exerciseName': 'squats',
#      'numberOfReps': 8,
#      'numberOfSets': 3},
#     {'description': 'Bench Press: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'bench press',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 2': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Pull-ups: 3 sets of 8 reps',
#      'duration': 30,
#      'exerciseName': 'pull-ups',
#      'numberOfReps': 8,
#      'numberOfSets': 3},
#     {'description': 'Dumbbell Rows: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'dumbbell rows',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 3': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Deadlifts: 3 sets of 8 reps',
#      'duration': 30,
#      'exerciseName': 'deadlifts',
#      'numberOfReps': 8,
#      'numberOfSets': 3},
#     {'description': 'Bicep Curls: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'bicep curls',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 4': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Leg Press: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'leg press',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Tricep Dips: 3 sets of 12 reps',
#      'duration': 30,
#      'exerciseName': 'tricep dips',
#      'numberOfReps': 12,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 5': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Shoulder Press: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'shoulder press',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Abs: 3 sets of 12 reps',
#      'duration': 30,
#      'exerciseName': 'abs',
#      'numberOfReps': 12,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]}},
#  'week 2': {'day 1': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Bench Press: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'bench press',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Incline Dumbbell Press: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'incline dumbbell press',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 2': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Lat Pulldowns: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'lat pulldowns',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Seated Row: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'seated row',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 3': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Leg Press: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'leg press',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Leg Extensions: 3 sets of 12 reps',
#      'duration': 30,
#      'exerciseName': 'leg extensions',
#      'numberOfReps': 12,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 4': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Shoulder Press: 3 sets of 10 reps',
#      'duration': 30,
#      'exerciseName': 'shoulder press',
#      'numberOfReps': 10,
#      'numberOfSets': 3},
#     {'description': 'Bicep Curls: 3 sets of 12 reps',
#      'duration': 30,
#      'exerciseName': 'bicep curls',
#      'numberOfReps': 12,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]},
#   'day 5': {'gymWorkout': [{'description': 'Warm-up: 5 minutes on the treadmill',
#      'duration': 5,
#      'exerciseName': 'treadmill',
#      'numberOfReps': 0,
#      'numberOfSets': 1},
#     {'description': 'Tricep Extensions: 3 sets of 12 reps',
#      'duration': 30,
#      'exerciseName': 'tricep extensions',
#      'numberOfReps': 12,
#      'numberOfSets': 3},
#     {'description': 'Abs: 3 sets of 12 reps',
#      'duration': 30,
#      'exerciseName': 'abs',
#      'numberOfReps': 12,
#      'numberOfSets': 3},
#     {'description': 'Cool-down: 5 minutes of stretching',
#      'duration': 5,
#      'exerciseName': 'stretching',
#      'numberOfReps': 0,
#      'numberOfSets': 1}]}}}
